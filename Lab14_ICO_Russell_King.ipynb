# %% [markdown]
# <a href="https://colab.research.google.com/github/kingruss-afk/Data-Mining-CSC-587/blob/main/Lab14_ICO_Russell_King.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #Generate a 2D dataset with non-convex clusters

# %%
X, y = make_moons(n_samples=300, noise=0.05, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Visualize
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])
plt.title("Dataset for DBSCAN")
plt.show()

# %% [markdown]
# #Applying DBSCAN

# %%
dbscan = DBSCAN(eps=0.3, min_samples=5)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.show()

# %% [markdown]
# #Can you change epsilon and min values to observe how things change? For instance,
#
# * Try eps=0.1, eps=0.5 and observe the difference.
# * What happens when you change min_samples to 3 or 10?
# * Can you also identify noise for each trial. (Hint: np.sum(labels == -1) after you your clusters)

# %%
# eps 0.1
dbscan = DBSCAN(eps=0.1, min_samples=5)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.show()

# Count noise points
print("Noise points:", np.sum(labels == -1))
# Out:
# Noise points: 136

# %%
# eps 0.5
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.show()

# Count noise points
print("Noise points:", np.sum(labels == -1))
# Out:
# Noise points: 0

# %%
# min samples = 3
dbscan = DBSCAN(eps=0.3, min_samples=3)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.show()

# Count noise points
print("Noise points:", np.sum(labels == -1))
# Out:
# Noise points: 0

# %%
# min samples = 10
dbscan = DBSCAN(eps=0.3, min_samples=10)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.show()

# Count noise points
print("Noise points:", np.sum(labels == -1))
# Out:
# Noise points: 2

# %% [markdown]
# #Use a real dataset:
# * Try load_iris() from sklearn.datasets.
# * Apply DBSCAN

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt

# Load iris dataset
iris = load_iris()
X = iris.data

# Standardize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=3)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.xlabel('Sepal length (scaled)')
plt.ylabel('Sepal width (scaled)')
plt.title('DBSCAN clustering on Iris Data')
plt.show()

# Count noise points
print(f"Noise points detected: {np.sum(labels == -1)}")
# Out:
# Noise points detected: 17
